# %%
import requests
from bs4 import BeautifulSoup

# %%
page = requests.get('https://www.astro.columbia.edu/events/colloquia')
contents = page.content

# %%
contents
# Out:
# b'<html>\n<head>\n<meta http-equiv="Content-Type" content="text/html; charset=UTF-8">\n<title>Columbia University Department of Astronomy</title>\n<link href=\'https://fonts.googleapis.com/css?family=Droid+Sans\' rel=\'stylesheet\' type=\'text/css\' />\n<link href=\'https://fonts.googleapis.com/css?family=Rambla:400,700&subset=latin,latin-ext\' rel=\'stylesheet\' type=\'text/css\'>\n<link type="text/css" rel="stylesheet" href="/css/main.min.css" />\n\n<script type="text/javascript" src="/js/jquery.js"></script>\n<script type="text/javascript" src="/js/jquery.qtip.js"></script>\n<link type="text/css" rel="stylesheet" href="/css/jquery.qtip.css" />\n<link type="text/css" rel="stylesheet" href="/css/eTable.css" />\n\n<script type="text/javascript">\n\t$(document).ready( function(){\n\t\t$(\'ul.row[title]\').qtip({\n\t\t\t\tposition: {\n\t\t\t\t\tmy: \'bottom left\',\n\t\t\t\t\ttarget: \'mouse\'\n\t\t\t\t} \n\t\t}); // end qtip\n\t}); // end ready\n</script>\n\n<script type="text/javascr
# ...

# %%
soup = BeautifulSoup(page.content, 'html.parser')

# %%
print(soup.prettify())
# Out:
# <html>
#  <head>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <title>
#    Columbia University Department of Astronomy
#   </title>
#   <link href="https://fonts.googleapis.com/css?family=Droid+Sans" rel="stylesheet" type="text/css"/>
#   <link href="https://fonts.googleapis.com/css?family=Rambla:400,700&amp;subset=latin,latin-ext" rel="stylesheet" type="text/css"/>
#   <link href="/css/main.min.css" rel="stylesheet" type="text/css">
#    <script src="/js/jquery.js" type="text/javascript">
#    </script>
#    <script src="/js/jquery.qtip.js" type="text/javascript">
#    </script>
#    <link href="/css/jquery.qtip.css" rel="stylesheet" type="text/css"/>
#    <link href="/css/eTable.css" rel="stylesheet" type="text/css"/>
#    <script type="text/javascript">
#     $(document).ready( function(){
# 		$('ul.row[title]').qtip({
# 				position: {
# 					my: 'bottom left',
# 					target: 'mouse'
# 				}
# 		}); // end qtip
# 	}); // end ready
#    </script>
# ...

# %%
list(soup.children)
# Out:
# [<html>
#  <head>
#  <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#  <title>Columbia University Department of Astronomy</title>
#  <link href="https://fonts.googleapis.com/css?family=Droid+Sans" rel="stylesheet" type="text/css"/>
#  <link href="https://fonts.googleapis.com/css?family=Rambla:400,700&amp;subset=latin,latin-ext" rel="stylesheet" type="text/css"/>
#  <link href="/css/main.min.css" rel="stylesheet" type="text/css">
#  <script src="/js/jquery.js" type="text/javascript"></script>
#  <script src="/js/jquery.qtip.js" type="text/javascript"></script>
#  <link href="/css/jquery.qtip.css" rel="stylesheet" type="text/css"/>
#  <link href="/css/eTable.css" rel="stylesheet" type="text/css"/>
#  <script type="text/javascript">
#  	$(document).ready( function(){
#  		$('ul.row[title]').qtip({
#  				position: {
#  					my: 'bottom left',
#  					target: 'mouse'
#  				}
#  		}); // end qtip
#  	}); // end ready
#  </script>
#  <script type="text/javascript">
# ...

# %%
[type(item) for item in list(soup.children)]
# Out:
# [bs4.element.Tag,
#  bs4.element.NavigableString,
#  bs4.element.Tag,
#  bs4.element.NavigableString,
#  bs4.element.Tag,
#  bs4.element.NavigableString,
#  bs4.element.NavigableString,
#  bs4.element.Tag,
#  bs4.element.NavigableString,
#  bs4.element.NavigableString,
#  bs4.element.Tag,
#  bs4.element.NavigableString,
#  bs4.element.Tag,
#  bs4.element.NavigableString,
#  bs4.element.NavigableString,
#  bs4.element.NavigableString,
#  bs4.element.Tag,
#  bs4.element.NavigableString,
#  bs4.element.Tag,
#  bs4.element.NavigableString,
#  bs4.element.NavigableString,
#  bs4.element.NavigableString,
#  bs4.element.Tag,
#  bs4.element.NavigableString,
#  bs4.element.NavigableString,
#  bs4.element.NavigableString]

# %%
html = list(soup.children)[2]

# %%
test = soup.find_all(text="/event?eid=")
test
# Out:
# []

# %%
events = soup.find_all('ul', class_='row odd') + soup.find_all('ul', class_='row even')
events
# Out:
# [<ul class="row odd" title="Black Holes in Low Mass Galaxies">
#  <li class="date"> 10/09/2019</li>
#  <li class="speaker"> Anil Seth, <em>University of Utah</em></li>
#  <li class="title"> Black Holes in Low Mass Galaxi ...</li>
#  <li class="host"> Marcel Agüeros</li>
#  <br/>
#  </ul>, <ul class="row odd">
#  <li class="date"> 10/23/2019</li>
#  <li class="speaker"> Caroline Morley, <em>UT Austin</em></li>
#  <li class="title"> Planet Atmospheres</li>
#  <li class="host"> David Kipping</li>
#  <br/>
#  </ul>, <ul class="row odd">
#  <li class="date"> 11/06/2019</li>
#  <li class="speaker"> Elena D'Onghia, <em>University of Wisconsin</em></li>
#  <li class="title"> Galactic Dynamics</li>
#  <li class="host"> Kathryn Johnston</li>
#  <br/>
#  </ul>, <ul class="row odd">
#  <li class="date"> 11/20/2019</li>
#  <li class="speaker"> Francesca Fragkoudi, <em>MPA, Garching</em></li>
#  <li class="title"> Milky Way/Galaxy Models</li>
#  <li class="host"> Kathryn Johnston</li>
#  <br/>
# ...

# %%
events[0].text
# Out:
# '\n 10/09/2019\n Anil Seth, University of Utah\n Black Holes in Low Mass Galaxi ...\n Marcel Agüeros\n\n'

# %%
print(events[0].prettify())
# Out:
# <ul class="row odd" title="Black Holes in Low Mass Galaxies">
#  <li class="date">
#   10/09/2019
#  </li>
#  <li class="speaker">
#   Anil Seth,
#   <em>
#    University of Utah
#   </em>
#  </li>
#  <li class="title">
#   Black Holes in Low Mass Galaxi ...
#  </li>
#  <li class="host">
#   Marcel Agüeros
#  </li>
#  <br/>
# </ul>

# %%
date = events[0].find(class_="date").get_text().strip()
title = events[0].find(class_="title").get_text().strip()
title_long = events[0].find(class_="title").get_text().strip()
speaker = events[0].find(class_="speaker").get_text().strip()

print(date,title_long,speaker)
# Out:
# 10/09/2019 Black Holes in Low Mass Galaxi ... Anil Seth, University of Utah

# %%
dates = soup.find_all('li', class_='date')
dates
# Out:
# [<li class="date"> Date</li>,
#  <li class="date"> 10/02/2019</li>,
#  <li class="date"> 10/09/2019</li>,
#  <li class="date"> 10/16/2019</li>,
#  <li class="date"> 10/23/2019</li>,
#  <li class="date"> 10/28/2019</li>,
#  <li class="date"> 11/06/2019</li>,
#  <li class="date"> 11/13/2019</li>,
#  <li class="date"> 11/20/2019</li>,
#  <li class="date"> 11/22/2019</li>,
#  <li class="date"> 12/04/2019</li>]

# %%
titles  = soup.find_all('li', class_='title')
# Out:
# [<li class="title"> Talk</li>,
#  <li class="title"> Magnetic rule over black hole  ...</li>,
#  <li class="title"> Black Holes in Low Mass Galaxi ...</li>,
#  <li class="title"> Cosmo-hydro sims of galaxies</li>,
#  <li class="title"> Planet Atmospheres</li>,
#  <li class="title"> MONDAY TALK: Planet Detection</li>,
#  <li class="title"> Galactic Dynamics</li>,
#  <li class="title"> Columbia Review - Cosmic Rays/ ...</li>,
#  <li class="title"> Milky Way/Galaxy Models</li>,
#  <li class="title"> FRIDAY: BIG APPLE COLLOQUIUM</li>,
#  <li class="title"> Cosmology</li>]

# %%
speakers = soup.find_all('li', class_='speaker')
# Out:
# [<li class="speaker"> Speaker</li>,
#  <li class="speaker"> Phil Armitage, <em>Stony Brook/CCA</em></li>,
#  <li class="speaker"> Anil Seth, <em>University of Utah</em></li>,
#  <li class="speaker"> Evan Schneider, <em>Princeton University</em></li>,
#  <li class="speaker"> Caroline Morley, <em>UT Austin</em></li>,
#  <li class="speaker"> Gaspar Bakos, <em>Princeton University</em></li>,
#  <li class="speaker"> Elena D'Onghia, <em>University of Wisconsin</em></li>,
#  <li class="speaker"> Ellen Zweibel, <em>University of Wisconsin</em></li>,
#  <li class="speaker"> Francesca Fragkoudi, <em>MPA, Garching</em></li>,
#  <li class="speaker"> Fiona Harrison, <em>CalTech</em></li>,
#  <li class="speaker"> Adam Lidz, <em>UPenn</em></li>]

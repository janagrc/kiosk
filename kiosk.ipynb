# %%
import requests
from bs4 import BeautifulSoup

# %%
page = requests.get('https://www.astro.columbia.edu/events/colloquia')
contents = page.content

# %%
contents
# Out:
# b'<html>\n<head>\n<meta http-equiv="Content-Type" content="text/html; charset=UTF-8">\n<title>Columbia University Department of Astronomy</title>\n<link href=\'https://fonts.googleapis.com/css?family=Droid+Sans\' rel=\'stylesheet\' type=\'text/css\' />\n<link href=\'https://fonts.googleapis.com/css?family=Rambla:400,700&subset=latin,latin-ext\' rel=\'stylesheet\' type=\'text/css\'>\n<link type="text/css" rel="stylesheet" href="/css/main.min.css" />\n\n<script type="text/javascript" src="/js/jquery.js"></script>\n<script type="text/javascript" src="/js/jquery.qtip.js"></script>\n<link type="text/css" rel="stylesheet" href="/css/jquery.qtip.css" />\n<link type="text/css" rel="stylesheet" href="/css/eTable.css" />\n\n<script type="text/javascript">\n\t$(document).ready( function(){\n\t\t$(\'ul.row[title]\').qtip({\n\t\t\t\tposition: {\n\t\t\t\t\tmy: \'bottom left\',\n\t\t\t\t\ttarget: \'mouse\'\n\t\t\t\t} \n\t\t}); // end qtip\n\t}); // end ready\n</script>\n\n<script type="text/javascript">\n\n  var _gaq = _gaq || [];\n  _gaq.push([\'_setAccount\', \'UA-25240324-1\']);\n  _gaq.push([\'_trackPageview\']);\n\n  (function() {\n    var ga = document.createElement(\'script\'); ga.type = \'text/javascript\'; ga.async = true;\n    ga.src = (\'https:\' == document.location.protocol ? \'https://ssl\' : \'http://www\') + \'.google-analytics.com/ga.js\';\n    var s = document.getElementsByTagName(\'script\')[0]; s.parentNode.insertBefore(ga, s);\n  })();\n\n</script>\n</head>\n<body>\n<div id="banner">\n\t<ul class="memberLinks">\n\t\t<li class="tucked"><a href="/login"> &raquo; Log In</a></li>\n\t</ul>\n        <div id="innerBanner">\n                <div id="homeLink">\n                        <a href="http://www.columbia.edu"><h2>Columbia University</h2></a>\n                        <a href="/"><h1>Department of Astronomy</h1></a>\n                </div>\n                <br>\n        </div>\n</div>\n\n<div id="navWrap">\n\t<ul id="mainNav">\n\t\t<li>\n\t\t\t<a href="/index" id="homeTab"><h3>About</h3></a>\n\t\t\t<ul class="subNav">\n\t\t\t\t<li><a href="/about">About Us</a></li>\n\t\t\t\t<li><a href="/news">News</a></li>\n\t\t\t\t<li><a href="/jobs">Job Opportunities</a></li>\n\t\t\t\t<li><a href="http://outreach.astro.columbia.edu/">Outreach</a></li>\n\t\t\t\t<li><a href="/~arlin/ASTROTOOLS/astrotools">AstroTools</a></li>\n\t\t\t\t<li><a href="/findUs">Find Us</a></li>\n\t\t\t\t<li><a href="/contact">Contact Us</a></li>\n\t\t\t\t<li><a href="/resources">Resources</a></li>\n\t\t\t\t<li><a href="/support">Support Us</a></li>\n\t\t\t\t<li><a href="/multimedia">Multimedia</a></li>\n       </ul>\n\t\t</li>\n\t\t<li>\n\t\t\t<a href="/directory/faculty" id="peopleTab"><h3>People</h3></a>\n\t\t\t<ul class="subNav">\n\t\t\t\t<li><a href="/directory/faculty">Faculty</a></li>\n\t\t\t\t<li><a href="/directory/researchers">Researchers</a></li>\n\t\t\t\t<li><a href="/directory/postdocs">Postdocs</a></li>\n\t\t\t\t<li><a href="/directory/grads">Grad Students</a></li>\n<!--\t\t\t\t<li><a href="/directory/ugrads">Undergrad Students</a></li>  -->\n\t\t\t\t<li><a href="/directory/staff">Staff</a></li>\n<!--\t\t\t\t<li><a href="/directory/visitors">Visitors</a></li> -->\n\t\t\t\t<li><a href="/events/visitors">Visitors</a></li>\n\t\t\t\t<li><a href="/directory/former">Former Members</a></li>\n\t\t\t</ul>\n\t\t</li>\n\t\t<li>\n\t\t\t<a href="/research/all"  id="researchTab"><h3>Research</h3></a>\n\t\t\t<ul class="subNav">\n\t\t\t\t<li><a href="/research/all">Topics</a></li>\n\t\t\t\t<li><a href="/research/facilities">Facilities</a></li>\n\t\t\t\t<li><a href="/research/collaborations">Collaborations</a></li>\n\t\t\t\t<li><a href="/research/ugrad">For Undergrads</a></li>\n\t\t\t</ul>\n\t\t</li>\n\t\t<li>\n\t\t\t<a href="/grad/intro"  id="academicsTab"><h3>Academics</h3></a>\n\t\t\t<ul class="subNav">\n\t\t\t\t<li><a href="/undergrad/intro">Undergrad</a></li>\n\t\t\t\t<li><a href="/grad/intro">Graduate</a></li>\n\t\t\t\t<li><a href="http://bulletin.columbia.e ...

# %%
soup = BeautifulSoup(page.content, 'html.parser')

# %%
print(event_soup.prettify())
# Out:
# <html>
#  <head>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <title>
#    Columbia University Department of Astronomy
#   </title>
#   <link href="https://fonts.googleapis.com/css?family=Droid+Sans" rel="stylesheet" type="text/css"/>
#   <link href="https://fonts.googleapis.com/css?family=Rambla:400,700&amp;subset=latin,latin-ext" rel="stylesheet" type="text/css"/>
#   <link href="/css/main.min.css" rel="stylesheet" type="text/css">
#    <script src="/js/jquery.js" type="text/javascript">
#    </script>
#    <link href="/css/event.css" rel="stylesheet" type="text/css"/>
#    <script type="text/javascript">
#     var _gaq = _gaq || [];
#   _gaq.push(['_setAccount', 'UA-25240324-1']);
#   _gaq.push(['_trackPageview']);
#
#   (function() {
#     var ga = document.createElement('script'); ga.type = 'text/javascript'; ga.async = true;
#     ga.src = ('https:' == document.location.protocol ? 'https://ssl' : 'http://www') + '.google-analytics.com/ga.js';
#     var s = document.getElementsByTagName('script')[0]; s.parentNode.insertBefore(ga, s);
#   })();
#    </script>
#   </link>
#  </head>
#  <body>
#   <div id="banner">
#    <ul class="memberLinks">
#     <li class="tucked">
#      <a href="/login">
#       » Log In
#      </a>
#     </li>
#    </ul>
#    <div id="innerBanner">
#     <div id="homeLink">
#      <a href="http://www.columbia.edu">
#       <h2>
#        Columbia University
#       </h2>
#      </a>
#      <a href="/">
#       <h1>
#        Department of Astronomy
#       </h1>
#      </a>
#     </div>
#     <br/>
#    </div>
#   </div>
#   <div id="navWrap">
#    <ul id="mainNav">
#     <li>
#      <a href="/index" id="homeTab">
#       <h3>
#        About
#       </h3>
#      </a>
#      <ul class="subNav">
#       <li>
#        <a href="/about">
#         About Us
#        </a>
#       </li>
#       <li>
#        <a href="/news">
#         News
#        </a>
#       </li>
#       <li>
#        <a href="/jobs">
#         Job Opportunities
#        </a>
#       </li>
#       <li>
#        <a href="http://outreach.astro.columbia.edu/">
#         Outreach
#        </a>
#       </li>
#       <li>
#        <a href="/~arlin/ASTROTOOLS/astrotools">
#         AstroTools
#        </a>
#       </li>
#       <li>
#        <a href="/findUs">
#         Find Us
#        </a>
#       </li>
#       <li>
#        <a href="/contact">
#         Contact Us
#        </a>
#       </li>
#       <li>
#        <a href="/resources">
#         Resources
#        </a>
#       </li>
#       <li>
#        <a href="/support">
#         Support Us
#        </a>
#       </li>
#       <li>
#        <a href="/multimedia">
#         Multimedia
#        </a>
#       </li>
#      </ul>
#     </li>
#     <li>
#      <a href="/directory/faculty" id="peopleTab">
#       <h3>
#        People
#       </h3>
#      </a>
#      <ul class="subNav">
#       <li>
#        <a href="/directory/faculty">
#         Faculty
#        </a>
#       </li>
#       <li>
#        <a href="/directory/researchers">
#         Researchers
#        </a>
#       </li>
#       <li>
#        <a href="/directory/postdocs">
#         Postdocs
#        </a>
#       </li>
#       <li>
#        <a href="/directory/grads">
#         Grad Students
#        </a>
#       </li>
#       <!--				<li><a href="/directory/ugrads">Undergrad Students</a></li>  -->
#       <li>
#        <a href="/directory/staff">
#         Staff
#        </a>
#       </li>
#       <!--				<li><a href="/directory/visitors">Visitors</a></li> -->
#       <li>
#        <a href="/events/visitors">
#         Visitors
#        </a>
#       </li>
#       <li>
#        <a href="/directory/former">
#         Former Members
#        </a>
#       </li>
#      </ul>
#     </li>
#     <li>
#      <a href="/research/all" id="researchTab">
#       <h3>
#        Research
#       </h3>
#      </a>
#      <ul class="subNav">
#       <li>
#        <a href="/research/all">
#         Topics
#        </a>
#       </li>
#       <li>
#        <a href="/research/facilities">
#         Facilities
#        </a>
#       </li>
#       <li>
#        <a href="/research/collaborations">
#         Collaborations
#        </a>
#       </li>
#       <li>
#        <a href="/research/ugrad">
#         For Undergrads
#        </a>
#       </li>
#      </ul>
#     </li>
#     <li>
#      <a href="/grad/intro" id="academicsTab">
#       <h3>
#        Academics
#       </h3>
#      </a>
#      <ul class="subNav">
#       <li>
#        <a href="/undergrad/intro">
#         Undergrad
#        </a>
#       </li>
#       <li>
#        <a href="/grad/intro">
#         Graduate
#        </a>
#       </li>
#       <li>
#        <a href="http://bulletin.columbia.edu/columbia-college/departments-instruction/search/?department=ASTR&amp;pl=0&amp;ph=10&amp;college=CC">
#         Courses
#        </a>
#       </li>
#      </ul>
#     </li>
#     <li>
#      <a href="/events/upcoming" id="eventsTab">
#       <h3>
#        Events
#       </h3>
#      </a>
#      <ul class="subNav">
#       <li>
#        <a href="/events/upcoming">
#         Upcoming Events
#        </a>
#       </li>
#       <li>
#        <a href="/events/colloquia">
#         Colloquia
#        </a>
#       </li>
#       <li>
#        <a href="/events/seminars">
#         Seminars
#        </a>
#       </li>
#       <li>
#        <a href="/events/annual">
#         Annual Events
#        </a>
#       </li>
#       <li>
#        <a href="/events/archives">
#         Past Events
#        </a>
#       </li>
#       <li>
#        <a href="http://outreach.astro.columbia.edu/">
#         For the Public
#        </a>
#       </li>
#       <li>
#        <a href="/events/weekly">
#         Weekly Events
#        </a>
#       </li>
#       <li>
#        <a href="/events/visitors">
#         Visitors
#        </a>
#       </li>
#      </ul>
#     </li>
#     <br>
#     </br>
#    </ul>
#   </div>
#   <div id="picWrap">
#    <div id="topPic">
#     <img src="/images/eventPic.jpg"/>
#    </div>
#   </div>
#   <div id="contentWrap">
#    <div class="content event">
#     <h6>
#      Colloquium
#     </h6>
#     <h3>
#      Cosmology
#     </h3>
#     <ul class="specs">
#      <li>
#       <strong>
#        Speaker:
#       </strong>
#       Adam Lidz,
#       <em>
#        UPenn
#       </em>
#      </li>
#      <li>
#       <strong>
#        Date:
#       </strong>
#       December 4, 2019
#      </li>
#      <li>
#       <strong>
#        Time:
#       </strong>
#       4:05 pm
#      </li>
#      <li>
#       <strong>
#        Location:
#       </strong>
#       Pupin 1402
#      </li>
#      <li>
#       <strong>
#        Host:
#       </strong>
#       Greg Bryan
#      </li>
#     </ul>
#     <p>
#      Cosmology
#     </p>
#     <p>
#      Followed by wine and cheese in Pupin 1402.
#     </p>
#     <p style="margin-top:20px; text-align: right; margin-right: 0;">
#      <a href="/events/upcoming">
#       More Events »
#      </a>
#     </p>
#    </div>
#    <ul class="sideNav">
#     <li class="topNav selected" id="eventsLi">
#      <a class="top" href="/events/upcoming" rel="#eventsLi">
#       Upcoming Events
#      </a>
#     </li>
#     <li class="topNav selected" id="collLi">
#      <a class="top" href="/events/colloquia" rel="#collLi">
#       Colloquia
#      </a>
#     </li>
#     <li class="topNav" id="semLi">
#      <a class="top" href="/events/seminars" rel="resLi">
#       Seminars
#      </a>
#     </li>
#     <li class="topNav" id="anntLi">
#      <a class="top" href="/events/annual" rel="annLi">
#       Annual Events
#      </a>
#     </li>
#     <li class="topNav" id="semLi">
#      <a class="top" href="/events/archives" rel="resLi">
#       All Semesters
#      </a>
#     </li>
#     <li class="topNav" id="pubLi">
#      <a class="top" href="http://outreach.astro.columbia.edu/">
#       For the Public
#      </a>
#     </li>
#     <ul class="bottom">
#      <li>
#       <a href="http://outreach.astro.columbia.edu/">
#        Upcoming Events
#       </a>
#      </li>
#      <li>
#       <a href="http://outreach.astro.columbia.edu/calendar/index.html">
#        Stargazing/Lectures
#       </a>
#      </li>
#      <li>
#       <a href="http://outreach.astro.columbia.edu/past/index.html">
#        Events Blog
#       </a>
#      </li>
#     </ul>
#    </ul>
#   </div>
#  </body>
# </html>
# <li class="topNav" id="weekLi">
#  <a class="top" href="/events/weekly">
#   Weekly Events
#  </a>
# </li>
# <li class="topNav" id="visLi">
#  <a class="top" href="/events/visitors">
#   Visitors
#  </a>
# </li>
# <div class="topStories">
#  <h3>
#   Upcoming Events
#  </h3>
#  <ul>
#   <style type="text/css">
#    .topStories li a .type {
# 				color: #777;
# 			}
# 			.topStories li a:hover .type {
# 				color: #fff;
# 			}
#   </style>
#   <li>
#    <a href="/event?eid=636">
#     <span class="type">
#      » Colloquium:
#     </span>
#     Magnetic rule over black hole accretion
#    </a>
#   </li>
#   <li>
#    <a href="/event?eid=626">
#     <span class="type">
#      » Colloquium:
#     </span>
#     Black Holes in Low Mass Galaxies
#    </a>
#   </li>
#   <li>
#    <a href="/event?eid=638">
#     <span class="type">
#      » Seminar:
#     </span>
#     Getting the boot: Lonely GRBs, enigmatic r-process, and the birth of neutron stars
#    </a>
#   </li>
#   <li>
#    <a href="/event?eid=627">
#     <span class="type">
#      » Colloquium:
#     </span>
#     Cosmo-hydro sims of galaxies
#    </a>
#   </li>
#   <li>
#    <a href="/event?eid=642">
#     <span class="type">
#      » Seminar:
#     </span>
#     BH spins
#    </a>
#   </li>
#  </ul>
# </div>
# <br/>
# <div id="extWrap">
#  <ul class="externalLinks">
#   <li class="main">
#    <h3>
#     <a href="http://www.columbia.edu/">
#      Columbia University
#     </a>
#    </h3>
#    <ul>
#     <li>
#      <a href="http://www.columbia.edu/cu/lweb/">
#       Library
#      </a>
#      (
#      <a href="http://www.columbia.edu/cu/lweb/services/hours/">
#       Hours
#      </a>
#      )
#     </li>
#     <li>
#      <a href="http://registrar.columbia.edu/academic-calendar/">
#       Academic Calendar
#      </a>
#     </li>
#     <li>
#      <a href="http://www.columbia.edu/content/admissions.html">
#       Admissions
#      </a>
#     </li>
#     <li>
#      <a href="https://courseworks.columbia.edu/">
#       CourseWorks
#      </a>
#     </li>
#     <li>
#      <a href="http://www.columbia.edu/cu/bulletin/uwb/">
#       Directory of Classes
#      </a>
#     </li>
#     <li>
#      <a href="http://www.columbia.edu/content/maps.html">
#       Maps
#      </a>
#     </li>
#     <br/>
#     <li>
#      <a href="http://www.columbia.edu/cu/physics/">
#       CU Physics
#      </a>
#     </li>
#     <li>
#      <a href="http://www.barnard.edu/">
#       Barnard College
#      </a>
#     </li>
#    </ul>
#   </li>
#   <li class="main">
#    <h3>
#     <a href="collaborators.html">
#      Affiliates
#     </a>
#    </h3>
#    <ul>
#     <li>
#      <a href="/collaborations">
#       Columbia Astrophysics Laboratory (CAL)
#      </a>
#     </li>
#     <li>
#      <a href="http://www.giss.nasa.gov/ ">
#       NASA - Goddard Institute for Space Studies
#      </a>
#     </li>
#     <li>
#      <a href="http://www.iscap.columbia.edu/">
#       Institute for Strings, Cosmology
# 				and Astroparticle Physics
#      </a>
#     </li>
#     <li>
#      <a href="http://www.astro.ubc.ca/lmt/alpaca">
#       Alpaca
#      </a>
#     </li>
#     <li>
#      <a href="http://mdm.kpno.noao.edu/">
#       MDM Observatory
#      </a>
#      (
#      <a href="http://mdm.kpno.noao.edu/schedule.html">
#       Schedule
#      </a>
#      )
#     </li>
#     <li>
#      <a href="http://www.bnl.gov/world/">
#       Brookhaven National Lab
#      </a>
#     </li>
#     <li>
#      <a href="/~astrobio/index.html">
#       Columbia Astrobiology
# 				Center
#      </a>
#     </li>
#    </ul>
#   </li>
#   <li class="main">
#    <h3>
#     <a href="http://research.amnh.org/astrophysics/index.php">
#      American Museum of Natural
# 			History (AMNH)
#     </a>
#    </h3>
#    <ul>
#     <li>
#      <a href="http://research.amnh.org/astrophysics/staff">
#       Staff
#      </a>
#     </li>
#     <li>
#      <a href="http://research.amnh.org/astrophysics/research">
#       Research
#      </a>
#     </li>
#     <li>
#      <a href="http://research.amnh.org/astrophysics/events">
#       Events
#      </a>
#     </li>
#    </ul>
#   </li>
#  </ul>
# </div>
# <li>
#  <a href="http://www.haydenplanetarium.org/index.php">
#   Hayden Planetarium
#  </a>
# </li>
# <li class="main last">
#  <h3>
#   <a href="">
#    Department Links
#   </a>
#  </h3>
#  <ul>
#   <li>
#    <a href="/about">
#     About Us
#    </a>
#   </li>
#   <li>
#    <a href="/news">
#     News
#    </a>
#   </li>
#   <li>
#    <a href="/findUs">
#     Find Us
#    </a>
#   </li>
#   <li>
#    <a href="/contact">
#     Contact Us
#    </a>
#   </li>
#   <li>
#    <a href="/resources">
#     Resources
#    </a>
#   </li>
#   <li>
#    <a href="/support">
#     Support Us
#    </a>
#   </li>
#   <li>
#    <a href="/multimedia">
#     Multimedia
#    </a>
#   </li>
#   <li>
#    <a href="/~arlin/ASTROTOOLS/astrotools">
#     AstroTools
#    </a>
#   </li>
#   <li>
#    <a href="https://docs.astro.columbia.edu/">
#     Computing Info
#    </a>
#   </li>
#   <br/>
#   <li>
#    <a href="http://columbiablueshift.weebly.com/">
#     Blueshift
#    </a>
#   </li>
#   <li>
#    <a href="https://wikis.cuit.columbia.edu/confluence/display/redshift/Resource+Wiki">
#     Undergrad Wiki
#    </a>
#   </li>
#  </ul>
# </li>
# <br/>
# <div id="footWrap">
#  <p id="copyright">
#   Copyright 2011 Columbia University
#  </p>
#  <br/>
#  <a class="social" href="https://www.flickr.com/photos/63795245@N08/" target="_blank" title="View our photostream on flickr">
#   <img src="/images/flickr.png"/>
#  </a>
#  <a class="social" href="https://twitter.com/#!/ColumbiaAstro" target="_blank" title="Follow us on Twitter">
#   <img src="/images/twitter.png"/>
#  </a>
#  <a class="social" href="https://www.facebook.com/profile.php?id=100001702533658" target="_blank" title="Become a Fan on Facebook">
#   <img src="/images/facebook.png"/>
#  </a>
#  <br/>
# </div>

# %%
event = soup.find_all("a", href=lambda href: href and "event?" in href)
i=1
link = "http://www.astro.columbia.edu" + event[i].get('href')
#print(link)
page = requests.get(link)
contents = page.content
event_soup = BeautifulSoup(page.content, 'html.parser')
p = event_soup.find_all("p")
abstract = p[0].get_text()
specs = event_soup.find("ul",class_="specs").get_text().strip()
speaker = event[i].find(class_="speaker").get_text().strip()
title = event[i].find(class_="title").get_text().strip()
date = events[i].find(class_="date").get_text().strip()
#print("Colloquium \n",specs,"\n",abstract,"\n",link,"\n\n")
#print(event_soup.prettify())
title = event_soup.find_all("div",class_="content event")
title = title[-1].find_all("h3")[0].get_text()
print(title)
# Out:
# Black Holes in Low Mass Galaxies

# %%
event = soup.find_all("a", href=lambda href: href and "event?" in href)
for i in range(0,len(event)):
    link = "http://www.astro.columbia.edu" + event[i].get('href')
    #print(link)
    page = requests.get(link)
    contents = page.content
    event_soup = BeautifulSoup(page.content, 'html.parser')
    p = event_soup.find_all("p")
    abstract = p[0].get_text()
    #print("abstract:",abstract)
    #print(event_soup.prettify)
    #long_title = event[i].get('title')
    specs = event_soup.find("ul",class_="specs").get_text().strip()
    speaker = event[i].find(class_="speaker").get_text().strip()
    #title = event[i].find(class_="title").get_text().strip()
    title = event_soup.find_all("div",class_="content event")
    title = title[-1].find_all("h3")[0].get_text()
    date = events[i].find(class_="date").get_text().strip()
    #print("Colloquium",date, "\n",title,"\n",speaker,"\n",abstract,"\n",link,"\n\n")
    print("Colloquium \n",title,"\n",specs,"\n",abstract,"\n",link,"\n\n")
# Out:
# Colloquium
#  Magnetic rule over black hole accretion
#  Speaker:Phil Armitage, Stony Brook/CCA
# Date:October 2, 2019
# Time:4:05 pm
# Location:Pupin 1402
# Host:Zoltan Haiman
#  The thin disk regime of accretion, where the accretion rate is neither too high as to exceed the Eddington limit, nor too low as to lead to radiative inefficiency, is often considered to be the simplest and best-understood case. It applies to many AGN and to the luminous states of X-ray binaries. Quantitative comparisons of thin disk theory to observations, however, are often found lacking. In this talk, I will argue that the properties of radiatively efficient accretion disks are dramatically modified in the presence of relatively weak net magnetic fields. Simulations suggest that disks in which the magnetic pressure becomes comparable to the gas or radiation pressure look very different from their weakly magnetized counterparts. Speculation points to a possible scenario in which the observable characteristics of black hole accretion are largely byproducts of how the magnetic flux threading the disk evolves over time.
#  http://www.astro.columbia.edu/event?eid=636
#
#
# Colloquium
#  Black Holes in Low Mass Galaxies
#  Speaker:Anil Seth, University of Utah
# Date:October 9, 2019
# Time:4:05 pm
# Location:1402 Pupin
# Host:Marcel Agüeros
#  Supermassive black holes are ubiquitous in massive galaxies, but it remains unclear how many sub-Milky Way mass galaxies have central black holes.  If low mass galaxies commonly host central black holes, these will make up the majority of massive black holes in the local universe.  From the demographics of these black holes we can place constraints on how supermassive black holes form in the early universe.  I will discuss my
# group’s discoveries of 10 black holes in nearby galaxies using adaptive optics kinematics observations.  These include the discovery of massive black holes in stripped galaxy nuclei, and the first dynamical measurements of central BHs with masses below one million solar masses.
#  http://www.astro.columbia.edu/event?eid=626
#
#
# Colloquium
#  Cosmo-hydro sims of galaxies
#  Speaker:Evan Schneider, Princeton University
# Date:October 16, 2019
# Time:4:05 pm
# Location:Pupin 1402
# Host:Mary Putman
#  Cosmo-hydro sims of galaxies
#  http://www.astro.columbia.edu/event?eid=627
#
#
# Colloquium
#  Planet Atmospheres
#  Speaker:Caroline Morley, UT Austin
# Date:October 23, 2019
# Time:4:05 pm
# Location:Pupin 1402
# Host:David Kipping
#  Planet Atmospheres
#  http://www.astro.columbia.edu/event?eid=628
#
#
# Colloquium
#  MONDAY TALK: Planet Detection
#  Speaker:Gaspar Bakos, Princeton University
# Date:October 28, 2019
# Time:4:05 pm
# Location:Pupin 1402
# Host:David Kipping
#  Planet Detection
#  http://www.astro.columbia.edu/event?eid=629
#
#
# Colloquium
#  Galactic Dynamics
#  Speaker:Elena D'Onghia, University of Wisconsin
# Date:November 6, 2019
# Time:4:05 pm
# Location:Pupin 1402
# Host:Kathryn Johnston
#  Galactic Dynamics
#  http://www.astro.columbia.edu/event?eid=630
#
#
# Colloquium
#  Columbia Review - Cosmic Rays/Magnetic Fields/Galaxies
#  Speaker:Ellen Zweibel, University of Wisconsin
# Date:November 13, 2019
# Time:4:05 pm
# Location:Pupin 1402
# Host:Kathryn Johnston
#  Columbia Review - Cosmic Rays/Magnetic Fields/Galaxies
#  http://www.astro.columbia.edu/event?eid=631
#
#
# Colloquium
#  Milky Way/Galaxy Models
#  Speaker:Francesca Fragkoudi, MPA, Garching
# Date:November 20, 2019
# Time:4:05 pm
# Location:Pupin 1402
# Host:Kathryn Johnston
#  Milky Way/Galaxy Models
#  http://www.astro.columbia.edu/event?eid=632
#
#
# Colloquium
#  FRIDAY: BIG APPLE COLLOQUIUM
#  Speaker:Fiona Harrison, CalTech
# Date:November 22, 2019
# Time:3:00 pm
# Location:NYU Kimmel center (room 802/Shorin)
# Host:NYU
#  Prof Harrison will discuss the decadal survey in the morning (10am-12pm), followed by the colloquium in the afternoon (3pm).
#  http://www.astro.columbia.edu/event?eid=633
#
#
# Colloquium
#  Cosmology
#  Speaker:Adam Lidz, UPenn
# Date:December 4, 2019
# Time:4:05 pm
# Location:Pupin 1402
# Host:Greg Bryan
#  Cosmology
#  http://www.astro.columbia.edu/event?eid=634

# %%
#TO DO
#get long titles
#parse date
#add conditional on how soon event is
#better formatting
#KIOSK THAT INFO
